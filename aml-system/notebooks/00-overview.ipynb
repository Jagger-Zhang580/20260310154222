# %% [markdown]
# # AML 反洗钱系统 - 端到端学习指南
#
# ## 系统架构
#
# ```
# DataWorks (数据集成) → Spark ETL (清洗转换) → 检测引擎 → 告警/报告
#        ↓                      ↓                  ↓
#    MinIO/OSS           PostgreSQL/Redis     Neo4j/ML模型
# ```
#
# ## 学习路径
#
# | # | Notebook | 场景 | 方法 |
# |---|----------|------|------|
# | 01 | 01-data-exploration | 数据探索 | EDA |
# | 02 | 02-rule-engine | 规则引擎 | 规则 |
# | 03 | 03-structuring-detection | 分拆交易 | 规则+统计 |
# | 04 | 04-rapid-flow-detection | 快进快出 | 时序分析 |
# | 05 | 05-graph-analysis | 关系网络 | 图分析(Neo4j) |
# | 06 | 06-ml-detection | 机器学习 | IsolationForest/XGBoost |
# | 07 | 07-time-series-anomaly | 时序异常 | Prophet/统计 |
# | 08 | 08-hybrid-detection | 混合检测 | 规则+图+ML融合 |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import json
import os

# 设置中文显示
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

print('环境准备完成!')
